# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline 
import pickle # salvar modelo

# %%
DW = pd.read_csv('use-of-force-DW.csv',sep=',')

# %%
plt.figure(figsize=(18,7))
sns.heatmap(DW.corr(),annot=True)

# %%
DW.describe()
# Out:
#         Unnamed: 0  INCIDENT_NUM   OFFICER_ID    SUBJECT_ID  \
# count  8061.000000   8061.000000  8061.000000   8061.000000
# mean   4030.000000  10988.216598  1545.556383   7608.108299
# std    2327.154593   7880.628574   560.138654   5218.218703
# min       0.000000    178.000000     7.000000      4.000000
# 25%    2015.000000   4034.000000  1172.000000   2888.000000
# 50%    4030.000000  10057.000000  1651.000000   6779.000000
# 75%    6045.000000  16258.000000  1820.000000  12226.000000
# max    8060.000000  31876.000000  4883.000000  17489.000000
#
#        INCIDENT_TYPE_LEVEL  SUBJECT_GENDER_NUM  SUBJECT_RACE_NUM  \
# count          8061.000000         8061.000000       8061.000000
# mean              1.235951            1.797792          4.699913
# std               0.424618            0.401672          1.537016
# min               1.000000            1.000000          1.000000
# 25%               1.000000            2.000000          3.000000
# ...

# %%
# Basic correlogram
#plt.figure(figsize=(18,7))
#sns.pairplot(DW)

# %%
DW.head(2)
# Out:
#    Unnamed: 0                ID  INCIDENT_NUM           INCIDENT_TYPE  \
# 0           0  18412-2238-14470         18412  Level 1 - Use of Force
# 1           1  16162-1589-12833         16162  Level 1 - Use of Force
#
#      OCCURED_DATE_TIME SECTOR  OFFICER_ID  SUBJECT_ID SUBJECT_GENDER  \
# 0  2017-11-28T01:40:00      -        2238       14470         Female
# 1  2017-06-22T04:15:00      -        1589       12833           Male
#
#                 SUBJECT_RACE    ...    BEAT_NUM SECTOR_NUM        DATE  \
# 0  Black or African American    ...          12          1  2017-11-28
# 1  Black or African American    ...          12          1  2017-06-22
#
#        TIME  YEAR  MONTH  DAY  MONTH_YEAR WEEK_NUM WEEK_YEAR
# 0  01:40:00  2017     11   28     11/2017       48   48/2017
# 1  04:15:00  2017      6   22     06/2017       25   25/2017
#
# [2 rows x 26 columns]

# %%
SELECAO_COLUNAS_X = ['OFFICER_ID','SUBJECT_ID', 'SUBJECT_GENDER_NUM', 'SUBJECT_RACE_NUM',
       'PRECINCT_NUM', 'BEAT_NUM', 'SECTOR_NUM','MONTH']
SELECAO_COLUNAS_Y = ['INCIDENT_TYPE_LEVEL']
DW.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'INCIDENT_NUM', 'INCIDENT_TYPE',
#        'OCCURED_DATE_TIME', 'SECTOR', 'OFFICER_ID', 'SUBJECT_ID',
#        'SUBJECT_GENDER', 'SUBJECT_RACE', 'PRECINCT', 'BEAT',
#        'INCIDENT_TYPE_LEVEL', 'SUBJECT_GENDER_NUM', 'SUBJECT_RACE_NUM',
#        'PRECINCT_NUM', 'BEAT_NUM', 'SECTOR_NUM', 'DATE', 'TIME', 'YEAR',
#        'MONTH', 'DAY', 'MONTH_YEAR', 'WEEK_NUM', 'WEEK_YEAR'],
#       dtype='object')

# %% [markdown]
# # TREINAMENTO

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(DW[SELECAO_COLUNAS_X], DW[SELECAO_COLUNAS_Y], test_size=0.3, random_state=101)

# %%
param_LR = {'penalty':('l1','l2'),
            'C':[1,2,3]}

param_FL = {'min_samples_leaf':[3,5,7,10], 
              'min_samples_split':[3,5,7,10], 
              'max_depth':[6,10,15,20], 
              'n_estimators':[2,5,8,10,15,20]}

# %%
ROBO_FL = GridSearchCV(RandomForestClassifier(), param_FL, cv=5, scoring='f1',verbose=3)
ROBO_LR = GridSearchCV(LogisticRegression(), param_LR, cv=5, scoring='f1',verbose=3)

# %%
ROBO_LR.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.8670346211741095, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.8670346211741095, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [CV] ........ C=1, penalty=l1, score=0.8664658634538153, total=   0.0s
# [CV] C=1, penalty=l1 .................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
ROBO_FL.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2, score=0.8710337768679631, total=   0.0s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2, score=0.8740970072239421, total=   0.0s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=3, n_estimators=2, score=0.8726899383983574, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
accuracy_score(y_test,ROBO_FL.predict(X_test))
# Out:
# 0.801984291029351

# %%
accuracy_score(y_test,ROBO_LR.predict(X_test))
# Out:
# 0.7610582885489872

# %%
print(classification_report(y_test, ROBO_FL.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.81      0.96      0.88      1841
#            2       0.70      0.30      0.42       578
#
#    micro avg       0.80      0.80      0.80      2419
#    macro avg       0.76      0.63      0.65      2419
# weighted avg       0.79      0.80      0.77      2419

# %%
print(classification_report(y_test, ROBO_LR.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.76      1.00      0.86      1841
#            2       0.50      0.01      0.02       578
#
#    micro avg       0.76      0.76      0.76      2419
#    macro avg       0.63      0.50      0.44      2419
# weighted avg       0.70      0.76      0.66      2419

# %%
from sklearn.model_selection import learning_curve
from sklearn.model_selection import validation_curve
from sklearn.model_selection import ShuffleSplit

# %%
def plot_learning_curve(estimator, title, X, y,):
    
    cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
    ylim=(0.7, 1.01)
    n_jobs=1
    train_sizes=np.linspace(.1, 1.0, 5)

    plt.figure()
    plt.title(title)
    plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
def model_complexity(estimator, title, param_name, values_param, scoring, X, y):
    """ Calculates the performance of the model as model complexity increases.
        The learning and testing errors rates are then plotted. """
    
    # Create 10 cross-validation sets for training and testing
    cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

    # Vary the max_depth parameter from 1 to 10

    # Calculate the training and testing scores
    train_scores, test_scores = validation_curve(estimator, X, y, \
        param_name = param_name, param_range = values_param, cv = cv, scoring = scoring)

    # Find the mean and standard deviation for smoothing
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plot the validation curve
    plt.figure(figsize=(7, 5))
    ylim=(0.7, 1.01)
    plt.ylim(*ylim)
    plt.title(title)
    plt.grid()
    plt.plot(values_param, train_mean, 'o-', color = 'r', label = 'Training Score')
    plt.plot(values_param, test_mean, 'o-', color = 'g', label = 'Validation Score')
    plt.fill_between(values_param, train_mean - train_std, \
        train_mean + train_std, alpha = 0.15, color = 'r')
    plt.fill_between(values_param, test_mean - test_std, \
        test_mean + test_std, alpha = 0.15, color = 'g')
    
    # Visual aesthetics
    plt.legend(loc = 'lower right')
    plt.xlabel('Maximum Depth')
    plt.ylabel('Score')
    plt.ylim([-0.05,1.05])
    plt.show()

# %%
title = "Learning Curves (Floresta Aleatoria)"
a = plot_learning_curve(ROBO_FL.best_estimator_, title, DW[SELECAO_COLUNAS_X], DW[SELECAO_COLUNAS_Y])
# Out:
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
title = "Learning Curves (Regressao Logistica)"
a = plot_learning_curve(ROBO_LR.best_estimator_, title, DW[SELECAO_COLUNAS_X], DW[SELECAO_COLUNAS_Y])
# Out:
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
param_name='max_depth'
values_param = np.arange(2,20)
scoring='f1'
title='Performance Floresta aleatória'
model_complexity(ROBO_FL.best_estimator_, title, param_name, values_param, scoring, DW[SELECAO_COLUNAS_X], DW[SELECAO_COLUNAS_Y])
# Out:
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
param_name='C'
values_param = np.arange(1,3)
scoring='f1'
title='Performance Regressao Logistica'
model_complexity(ROBO_LR.best_estimator_, title, param_name, values_param, scoring, DW[SELECAO_COLUNAS_X], DW[SELECAO_COLUNAS_Y])
# Out:
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
#para salvar um modelo
pickle.dump(ROBO_FL, open('ROBO_FL.sav', 'wb'))
pickle.dump(ROBO_LR, open('ROBO_LR.sav', 'wb'))

#para carregar um modelo
#GRID_FL = pickle.load(open('C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/MODELOS/GRID_FL_PROBL_1_SEM_VOTOS_3.sav', 'rb'))
